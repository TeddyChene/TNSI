# %% [markdown]
# <div style="width:60%;margin:auto;padding:10px;font-size:4em;text-align:center;font-family:Roman,serif;">
#     <p style="padding:10px;text-align:center">Le langage SQL</p>
# </div>

# %% [markdown]
# <span style="font-size:2em;font-family:roman,serif;font-weight:bold;">Activité - Comment interroger une base de données ?</span>

# %% [markdown]
# ![banniere_lol-v2.png](attachment:banniere_lol-v2.png)

# %% [markdown]
# <ol style="font-family:roman,serif;font-size:1.5em;list-style-type: none;">
#     <li>Le <span style="color:blue">modèle relationnel</span> de cette base de données est présenté ci-dessous :<li>
# </ol>

# %% [markdown]
# ![lol-schema-relationnel-sqlite.png](attachment:lol-schema-relationnel-sqlite.png)

# %% [markdown]
# <ol start="1" style="font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>Après avoir <a href="https://ent.lyclpg.itereva.pf/moodle/mod/resource/view.php?id=36655" target="_blank">téléchargé la base de données</a> sur votre support, charger la base de données sur Basthon : <br>
#         <center>Fichier > Ouvrir > <code>league_of_legends_db.sqlite</code></center>
#     </li>
# </ol>

# %% [markdown]
# <ol start="2" style="font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>Écrire, éxécuter puis décrire les différentes requêtes SQL ci-dessous :</li>
# </ol>

# %% [markdown]
# ![act3-req-sql.png](attachment:act3-req-sql.png)

# %% [markdown]
# **Description :**

# %% [markdown]
# **Description :**

# %% [markdown]
# **Description :**

# %% [markdown]
# **Description :**

# %% [markdown]
# <ol start="2" style="font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>Les fonctions d’agrégation dans le langage SQL permettent d’effectuer des opérations statistiques sur une colonne (en général de type numérique). <br>Rechercher puis compléter la description des fonctions ci-dessous :</li>
# </ol>

# %% [markdown]
# ``COUNT()`` :
#
# ``MAX()`` :
#
# ``MIN()`` :
#
# ``SUM()`` :
#
# ``AVG()`` :

# %% [markdown]
# <ol start="3" style="font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>À l'aide des fonctions précédente, écrire les différentes requêtes ci-dessous :</li>
# </ol>

# %% [markdown]
# <ol start="4" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol>
#             <li type="a">Combien y-a-t-il de champions de type <code>carry</code> ?</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="4" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol start="2">
#             <li type="a">Quel est le maximum de vie <code>Health</code> qu’un champion possède en début de partie?
# </li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="4" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol start="3">
#             <li type="a">Quel est le minimum d’armure <code>Armor</code> qu’un champion possède en début de partie?
# </li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="4" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol start="4">
#             <li type="a">Quelle est la moyenne des dégâts <code>Damage</code> des champions présents dans cette base?
# </li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <span style="font-size:2em;font-family:roman,serif;font-weight:bold;">Exercice - Comment interroger une base de données ?</span>

# %% [markdown]
# <span style="font-family:roman,serif;font-size:1.5em;line-height:1.5em">Dans cet exercice on utilie la base de données <code>league_of_legends_db</code>.<br>
#     Pour chacune des questions de cet exercice, écrire les requêtes SQL.</span>

# %% [markdown]
# <ol start="1" style="font-family:roman,serif;font-size:1.5em">
#     <li>Dans la relation <code>champions</code> :</li>
# </ol>

# %% [markdown]
# <ol start="1" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol>
#             <li type="a">Lister tous les attributs des champions de type <code>'ranged'</code>.</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="1" style="list-style-type:none;font-family:roman,serif;font-size:1.5em ;line-height:1.5em">
#     <li>
#         <ol start="2">
#             <li type="a">Lister le nom <code>name</code> et l’histoire <code>lore</code> de tous les champions de type <code>'assassin'</code></li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="1" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol start="3">
#             <li type="a">Lister, dans l’ordre croissant suivant le nom du champion, le nom <code>name</code> et le titre <code>title</code> des champions dont le nom commence par la lettre « A ».</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="1" style="list-style-type:none;font-family:roman,serif;font-size:1.5em">
#     <li>
#         <ol start="4">
#             <li type="a">Lister tous les attributs des champions de type <code>'melee'</code> et <code>'carry'</code>.</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="1" style="list-style-type:none;font-family:roman,serif;font-size:1.5em">
#     <li>
#         <ol start="5">
#             <li type="a">Déterminer le nombre de champions de type <code>'jungler'</code>.</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="1" style="list-style-type:none;font-family:roman,serif;font-size:1.5em">
#     <li>
#         <ol start="6">
#             <li type="a">Déterminer le nombre de champions de type <code>'assassin'</code> qui ne sont pas de type <code>'melee'</code>.</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="2" style="font-family:roman,serif;font-size:1.5em">
#     <li>Dans la relation <code>champion_abilities</code> :</li>
# </ol>

# %% [markdown]
# <ol start="2" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol start="1">
#             <li type="a">Lister tous les attributs des capacités des champions dont la distance <code>range</code> est comprise entre 1000 et 2000 unités.</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="2" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol start="2">
#             <li type="a">Lister, par ordre décroissant des distances <code>range</code>, tous les attributs des capacités des champions dont la distance est strictement supérieure à 2000 unités.</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="2" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol start="3">
#             <li type="a">Lister, par ordre croissant des identifiants des champions, tous les attributs des capacités des champions dont la distance est strictement inférieure à 1000 unités et dont le nom de la capacité commence par « A ».</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="2" style="list-style-type:none;font-family:roman,serif;font-size:1.5em">
#     <li>
#         <ol start="4">
#             <li type="a">Lister tous les attributs des capacités du champion Teemo à l’aide d’une seule requête SQL.</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="2" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol start="5">
#             <li type="a">Lister, par ordre croissant des identifiants des champions, tous les attributs des capacités des champions de type <code>'mage'</code> et <code>'melee'</code> à l’aide d’une seule requête SQL.</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="3" style="font-family:roman,serif;font-size:1.5em">
#     <li>Dans la relation <code>champion_stats</code> :</li>
# </ol>

# %% [markdown]
# <ol start="3" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol start="1">
#             <li type="a">Lister tous les noms de caractéristiques différents pour un champion.</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="3" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol start="2">
#             <li type="a">Afficher le minimum, le maximum et la moyenne des dégâts <code>Damage</code> qu’un champion peut faire.</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="3" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol start="3">
#             <li type="a">Afficher les caractéristiques du champion <code>Master Yi</code>.</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="3" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol start="4">
#             <li type="a">Afficher le minimum, le maximum et la moyenne de Mana des champions de type <code>'mage'</code>.</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="4" style="font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>Chacune des relations utilisées dans les questions précédentes ont en commun l’identifiant du champion. Il semble donc intéressant de pouvoir afficher différents attributs issus de différentes relations avec une même requête.</li>
# </ol>

# %% [markdown]
# <ol start="3" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol start="1">
#             <li type="a">Exécuter puis décrire la requête SQL ci-dessous :</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# **Description :**

# %% [markdown]
# <ol start="3" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol start="2">
#             <li type="a">Afficher le nom, le titre, les tags et les conseils des champions de type <code>'jungler'</code> et <code>'ranged'</code>.</li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="3" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol start="3">
#             <li type="a">Afficher le nom, les tags, les caractéristiques <code>stats</code> et les valeurs des caractéristiques du champion <code>Garen</code>.
# </li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="3" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol start="4">
#             <li type="a">Afficher le nom, le nom des capacités <code>abilities</code> et la distance des capacités <code>range</code> des 5 champions ayant le plus grand <code>range</code>.
# </li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# <ol start="3" style="list-style-type:none;font-family:roman,serif;font-size:1.5em;line-height:1.5em">
#     <li>
#         <ol start="5">
#             <li type="a">Afficher le nom, le nom des caractéristiques <code>stats</code>, la valeur de base de la caractéristique et le gain par niveau <code>modifier_per_level</code> des 5 champions gagnant le plus de points de dégâts <code>damage</code> par niveau gagné.
# </li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# CHENE Teddy - Lycée Paul Gauguin, ressource éducative libre distribuée sous
# [Licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International](http://creativecommons.org/licenses/by-nc-sa/4.0/) ![Licence Creative Commons](https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png)
